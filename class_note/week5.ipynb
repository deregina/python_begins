# %% [markdown]
# **총 복습**<br>
# - 입출력
# - 문자열
# - 리스트, 딕셔너리
# - 반복/조건문
# - 함수 : def 함수 이름 (인자argument ):
#     함수 코드 내용
#     return ()
#
# **문제**
# - [10171 고양이](https://www.acmicpc.net/problem/10171): 입출력
# - L=[11, 10, 83, 25, 28]의 원소들을 오른쪽으로 한 칸씩 쉬프트(rotate right)하여 출력하시오. : 리스트
# - [2675 문자열 반복](https://icpc.me/2675) : 문자열, 반복
# - [14405: 피카츄](https://www.acmicpc.net/problem/14405) 인덱스: 문자열, 반복조건문
# - 문장을 입력 받으면, 그 문장을 구성하는 단어들의 개수와 단어들의 평균길이를 구하시오.: 함수 만들어서 풀기

# %%
# L=[11, 10, 83, 25, 28]의 원소들을 오른쪽으로 한 칸씩 쉬프트(rotate right)하여 출력하시오. : 리스트 의 확장
while True:
    l = list(map(int, input("list of numbers: ").split()))
    _len = len(l)
    move = int(input("Move: "))
    if move > _len:
        print("move should be smaller than length of the list")
        continue
    
    direction = input("Direction(L/R): ").lower()
    l = l+l
    
    if direction == "l":
        result = l[move:move+_len]
    elif direction == "r":
        result = l[(_len-move):(_len-move)+_len]
    else:
        print("direction should be either L or R")

    print(result)
    
    if input("Continue? Y/N: ").lower() == 'y':
        break

# %%
# 문장을 입력 받으면, 그 문장을 구성하는 단어들의 개수와 단어들의 평균길이를 구하시오.: 함수 만들어서 풀기
def count_average():
    ()
    return ()

# 문장 입력
sentence
count_average(sentence)
print(평균, 단어 개수 )

# %% [markdown]
# # 파일 입출력
#
# 연다 - 읽거나 쓴다 - 닫는다 <br>
# "r", "w", "a", "r+"
#
# 1. txt 파일
# 2. csv 파일

# %%
f = open("./example.txt", 'w')
for i in range(1, 11):
    data = "%d\n" % i
    f.write(data)

# %%
line = f.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-3-9cc63bfe0f9e> in <module>
# ----> 1 line = f.read()
#
# UnsupportedOperation: not readable

# %%
f.close()

# %%
f = open("./example.txt", 'r')
line1 = f.readline()
print("line1\n", line1, sep="")
f.readline()
line2 = f.read()
print("line2\n", line2, sep="")
lines = f.readlines()
print("lines\n", lines, sep="")

line1, line2, lines = map(type, (line1, line2, lines))
print(line1, line2, lines)
f.close()
# Out:
# line1
# 1
#
# line2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
#
# lines
# []
# <class 'str'> <class 'str'> <class 'list'>

# %%
with open("../python.txt", "w") as f:
    f.write("Life is too short, you need python")

# %%
with open("./2675.txt", 'w') as f:
    f.write("2\n")
    f.write("3 ABC\n")
    f.write("5 /HTP\n")

# %% [markdown]
# # csv파일과 pandas

# %%
import pandas as pd
# from pandas import read_csv

# %%
filepath = "./example.csv"
df = pd.read_csv(filepath, encoding="cp949")

# %%
df
# Out:
#         구분  강력범죄   절도범죄   폭력범죄   지능범죄  풍속범죄  특별경제범죄  마약범죄  보건범죄  환경범죄   교통범죄  \
# 0       서울  6683  46861  64601  72137  5647   17109  1449  3875    58  74270
columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.index
# Out:
# RangeIndex(start=0, stop=87, step=1)

# %%
df.columns
# Out:
# Index(['구분', '강력범죄', '절도범죄', '폭력범죄', '지능범죄', '풍속범죄', '특별경제범죄', '마약범죄', '보건범죄',
#        '환경범죄', '교통범죄', '노동범죄', '안보범죄', '선거범죄', '병역범죄', '기타범죄'],
#       dtype='object')

# %%
df.iloc[0:5, 1:5]
# Out:
#    강력범죄   절도범죄   폭력범죄   지능범죄
# 0  6683  46861  64601  72137
# 1  1630  16777  20444  25052
# 2  1028   9171  14557  13227
# 3  1817  10025  19881  17248
# 4   796   6050   8610   8896

# %%
df.loc[:, 0:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-ce4050f9bc00> in <module>
# ----> 1 df.loc[:, 0:5]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     886                 continue
#     887
# --> 888             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     889
#     890         return retval
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1865         if isinstance(key, slice):
#    1866             self._validate_key(key, axis)
# -> 1867             return self._get_slice_axis(key, axis=axis)
#    1868         elif com.is_bool_indexer(key):
#    1869             return self._getbool_axis(key, axis=axis)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1531         labels = obj._get_axis(axis)
#    1532         indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop,
# -> 1533                                        slice_obj.step, kind=self.name)
#    1534
#    1535         if isinstance(indexer, slice):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    4670         """
#    4671         start_slice, end_slice = self.slice_locs(start, end, step=step,
# -> 4672                                                  kind=kind)
#    4673
#    4674         # return a slice
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    4869         start_slice = None
#    4870         if start is not None:
# -> 4871             start_slice = self.get_slice_bound(start, 'left', kind)
#    4872         if start_slice is None:
#    4873             start_slice = 0
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    4795         # For datetime indices label may be a string that has to be converted
#    4796         # to datetime boundary according to its resolution.
# -> 4797         label = self._maybe_cast_slice_bound(label, side, kind)
#    4798
#    4799         # we need to look up the label
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexes/base.py in _maybe_cast_slice_bound(self, label, side, kind)
#    4747         # this is rejected (generally .loc gets you here)
#    4748         elif is_integer(label):
# -> 4749             self._invalid_indexer('slice', label)
#    4750
#    4751         return label
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexes/base.py in _invalid_indexer(self, form, key)
#    3064                         "indexers [{key}] of {kind}".format(
#    3065                             form=form, klass=type(self), key=key,
# -> 3066                             kind=type(key)))
#    3067
#    3068     # --------------------------------------------------------------------
#
# TypeError: cannot do slice indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [0] of <class 'int'>

# %%
df.loc[:,'강력범죄':'지능범죄']
# Out:
# 강력범죄     6683
# 절도범죄    46861
# 폭력범죄    64601
# 지능범죄    72137
# Name: 0, dtype: object

# %%
filepath = "./example.csv"
df1 = pd.read_csv(filepath, index_col=[0], header=0, encoding="cp949")

# %%
df1
# Out:
#         강력범죄   절도범죄   폭력범죄   지능범죄  풍속범죄  특별경제범죄  마약범죄  보건범죄  환경범죄   교통범죄  \
# 구분
# 서울      6683  46861  64601  72137  5647   17109  1449  3875    58  74270
# 부산      1630  16777  20444  25052  2201    8134   963  2365   223  32944
# 경기 의정부   38260  1570  1010  1040   2600   21640
# ...        ...   ...   ...   ...    ...     ...
# 전북 익산    31880  1040  1000  1190   1650   16390
# 전북 전주    56800  1200  1000  1220   2610   29710
# 전북 정읍    11950  1030  1000  1050   1180    4690
# 전남 광양    25500  1030  1000  1050   1170    4900
# 전남 나주     3530  1000  1000  1030   1020    2030
# 전남 목포    44560  1270  1000  1040   1980   18580
# 전남 순천    51240  1070  1000  1030   1650    9230
# 전남 여수    50750  1060  1000  1240   1590   12430
# 경북 경산    24440  1110  1000  1000   1960    9760
# 경북 경주    38940  1030  1000  1010   1500   10130
# 경북 구미    86520  1210  1000  1100   2990   15140
# 경북 김천    20160  1020  1000  1010   1200    5130
# 경북 문경    10200  1010  1000  1000   1100    3110
# 경북 상주    12120  1030  1000  1100   1160    3330
# 경북 안동    17090  1030  1000  1110   1250    6510
# 경북 영주    13270  1100  1000  1000   1150    3850
# 경북 영천    12540  1000  1000  1030   1200    3820
# 경북 포항    75880  1190  1000  1060   2370   19280
# 경남 거제    49200  1210  1000  1040   2040   13230
# 경남 김해    74460  1330  1000  1140   2730   21360
# 경남 밀양    13430  1010  1010  1010   1370    4920
# 경남 사천    20080  1030  1000  1030   1150    6340
# 경남 양산    38600  1110  1000  1080   2640   15760
# 경남 진주    38490  1120  1000  1180   1800   14490
# 경남 창원   126940  1780  1040  1230   3920   46350
# 경남 통영    25300  1700  1000  1040   1410   24080
# 제주 서귀포   41600  1030  1000  1050   1840   13650
# 제주 제주   117420  1080  1020  1120   2450   35800
# 기타도시     13870  1030  1020  1060   1620   12870
# 도시이외    440900  1670  1030  2290   8610  180840
#
# [87 rows x 15 columns]

# %%
df1.index
# Out:
# Index(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기 고양', '경기 과천',
#        '경기 광명', '경기 광주', '경기 구리', '경기 군포', '경기 김포', '경기 남양주', '경기 동두천',
#        '경기 부천', '경기 성남', '경기 수원', '경기 시흥', '경기 안산', '경기 안성', '경기 안양', '경기 양주',
#        '경기 여주', '경기 오산', '경기 용인', '경기 의왕', '경기 의정부', '경기 이천', '경기 파주', '경기 평택',
#        '경기 포천', '경기 하남', '경기 화성', '강원 강릉', '강원 동해', '강원 삼척', '강원 속초', '강원 원주',
#        '강원 춘천', '강원 태백', '충북 제천', '충북 청주', '충북 충주', '충남 계룡', '충남 공주', '충남 논산',
#        '충남 당진', '충남 보령', '충남 서산', '충남 아산', '충남 천안', '전북 군산', '전북 김제', '전북 남원',
#        '전북 익산', '전북 전주', '전북 정읍', '전남 광양', '전남 나주', '전남 목포', '전남 순천', '전남 여수',
#        '경북 경산', '경북 경주', '경북 구미', '경북 김천', '경북 문경', '경북 상주', '경북 안동', '경북 영주',
#        '경북 영천', '경북 포항', '경남 거제', '경남 김해', '경남 밀양', '경남 사천', '경남 양산', '경남 진주',
#        '경남 창원', '경남 통영', '제주 서귀포', '제주 제주', '기타도시', '도시이외'],
#       dtype='object', name='구분')

# %%
df1.columns
# Out:
# Index(['강력범죄', '절도범죄', '폭력범죄', '지능범죄', '풍속범죄', '특별경제범죄', '마약범죄', '보건범죄',
#        '환경범죄', '교통범죄', '노동범죄', '안보범죄', '선거범죄', '병역범죄', '기타범죄'],
#       dtype='object')

# %%
df2 = pd.DataFrame(df1, columns=['강력범죄', '지능범죄'])

# %%
df2
# Out:
#          강력범죄    지능범죄
# 구분
# 서울      67830  722370
# 부산      17300  251520
# 대구      11280  133270
# 인천      19170  173480
# 광주       8960   89960
# 대전       8240   90790
# 울산       6230   62200
# 세종       1580    9210
# 경기 고양    4820   54070
# 경기 과천    1250    3800
# 경기 광명    2430   16010
# 경기 광주    2040   17620
# 경기 구리    2360   16010
# 경기 군포    1960   15250
# 경기 김포    2340   23000
# 경기 남양주   3660   30010
# 경기 동두천   1530    6920
# 경기 부천    6300   65510
# 경기 성남    6250   56700
# 경기 수원    7540   72770
# 경기 시흥    3210   29560
# 경기 안산    5910   54760
# 경기 안성    1860   10250
# 경기 안양    3980   32140
# 경기 양주    1710   12900
# 경기 여주    1700    7660
# 경기 오산    2030   11610
# 경기 용인    3670   40160
# 경기 의왕    1360    5390
# 경기 의정부   3420   26730
# ...       ...     ...
# 전북 익산    2330   15890
# 전북 전주    3740   36670
# 전북 정읍    1440    7260
# 전남 광양    1590    8020
# 전남 나주    1120    3250
# 전남 목포    2650   16050
# 전남 순천    2220   12440
# 전남 여수    2060   21530
# 경북 경산    2000   12940
# 경북 경주    2080   14380
# 경북 구미    2410   31910
# 경북 김천    1400    5790
# 경북 문경    1230    3250
# 경북 상주    1300    4170
# 경북 안동    1650   15950
# 경북 영주    1250    6930
# 경북 영천    1320    6340
# 경북 포항    2920   28820
# 경남 거제    2140   21160
# 경남 김해    2880   32660
# 경남 밀양    1310    6380
# 경남 사천    1420    6580
# 경남 양산    2280   16600
# 경남 진주    2270   16610
# 경남 창원    4570   67820
# 경남 통영    1500    9580
# 제주 서귀포   2280   10550
# 제주 제주    4650   32080
# 기타도시     1620   21550
# 도시이외    15700  184000
#
# [87 rows x 2 columns]

# %%
df2.to_csv("./example_output.csv")

# %% [markdown]
# # 클래스 --> 궁금한거 두개 이상 적어오기~
# 객체이름.메소드
#
#
# 1. __init__으로 미리 다 지정해주는 이유??
# 2. isOn은 True / Flase면, 1/0입력해도 되나??
# 3. __init__에서 연산은 불가능?

# %%
class TV:
    def __init__(self, channel, volume, isOn):
        self.channel = channel
        self.volume = volume
        self.isOn = isOn
    
    def turnOn(self):
        self.isOn = True
    
    def turnOff(self):
        self.isOn = False
        
    def setChannel(self, channel):
        self.channel = channel
        
    def setVolume(self, volume):
        self.volume = volume
        
    def status(self):
        print("Channel: ", self.channel)
        print("Volume: ", self.volume)

# %%
tv = TV(5, 8, True)

# %%
tv

# %%
tv.status()
# Out:
# Channel:  5
# Volume:  8

# %%
tv.setChannel(15)

# %%
tv.status()
# Out:
# Channel:  15
# Volume:  8

# %%
tv.turnOn()
